['rong2016visual', 'rong', 2016,'x','x','o','o','x','x','o','o','o','x','o','x','o','o','o','x','o','o','o','x','ICML VIS'],
['smilkov2016embedding', 'smilkov', 2016,'x','o','o','o','o','x','o','o','o','x','x','x','o','x','o','x','o','o','o','x','NIPS Workshop'],
['smilkov2017direct', 'smilkov', 2017,'x','x','o','x','o','o','x','x','x','x','o','o','x','o','x','o','x','o','x','x','ICML VIS'],
['strobelt2017lstmvis', 'strobelt', 2017,'x','x','o','o','x','x','o','o','o','x','x','x','o','x','o','x','o','o','o','x','TVCG'],
['tzeng2005opening', 'tzeng', 2005,'x','o','o','o','x','o','o','x','x','o','o','x','x','o','x','o','o','o','o','x','VIS'],
['wang2018ganviz', 'wang', 2018,'x','x','x','o','x','o','o','o','x','x','o','x','o','x','x','x','o','o','x','o','TVCG'],
['webster2017teachable', 'webster', 2017,'o','o','o','x','o','o','x','o','o','o','o','o','o','o','o','x','x','o','x','x','Web'],
['wongsuphasawat2018visualizing', 'wongsuphasawat', 2018,'o','x','o','o','x','o','o','x','o','o','o','x','x','o','o','o','o','o','o','o','TVCG'],
['yosinski2015understanding', 'yosinski', 2015,'x','o','o','x','o','x','x','x','x','x','o','o','o','o','o','x','x','x','o','x','ICML DL'],
['zahavy2016graying', 'zahavy', 2016,'x','x','o','o','x','o','o','o','o','x','x','x','o','x','o','x','o','o','o','x','ICML'],
['zeiler2014visualizing', 'zeiler', 2014,'x','x','o','o','x','o','o','o','x','x','o','o','o','o','o','o','o','x','o','x','ECCV'],
['zeng2017cnncomparator', 'zeng', 2017,'x','o','x','o','x','o','o','x','o','x','o','o','o','o','o','x','o','o','x','o','VADL'],
['zhong2017evolutionary', 'zhong', 2017,'x','x','o','o','x','o','o','o','o','x','x','x','o','x','x','x','o','x','x','o','ICML VIS'],
['zhu2016generative', 'zhu', 2016,'x','o','o','o','x','x','x','o','o','o','o','x','o','o','o','x','x','x','o','x','ECCV']
]

# %%
papers = []
for datum in data:
    paper = {}
    paper['paper'] = datum[0]
    paper['year'] = datum[1]
    paper['interpretability'] = datum[2]
    paper['debugging'] = datum[3]
    paper['comparing'] = datum[4]
    paper['education'] = datum[5]
    paper['model-developers'] = datum[6]
    paper['model-users'] = datum[7]
    paper['non-experts'] = datum[8]
    paper['graph'] = datum[9]
    paper['learned'] = datum[10]
    paper['units'] = datum[11]
    paper['neurons'] = datum[12]
    paper['aggregated'] = datum[13]
    paper['node-link'] = datum[14]
    paper['scatter'] = datum[15]
    paper['line'] = datum[16]
    paper['instance-based'] = datum[17]
    paper['interactive-experimentation'] = datum[18]
    paper['algorithms'] = datum[19]
    paper['during'] = datum[20]
    paper['after'] = datum[21]
    paper['venue'] = datum[22]
# Out:
#   File "<ipython-input-27-07cb0b33262b>", line 2
#     ]papers = []
#     ^
# SyntaxError: invalid syntax

# %%
papers
# Out:
# [{'after': 'x',
#   'aggregated': 'x',
#   'algorithms': 'o',
#   'comparing': 'x',
#   'debugging': 'x',
#   'during': 'x',
#   'education': 'o',
#   'graph': 'o',
#   'instance-based': 'o',
#   'interactive-experimentation': 'o',
#   'interpretability': 'x',
#   'learned': 'o',
#   'line': 'x',
#   'model-developers': 'x',
#   'model-users': 'x',
#   'neurons': 'o',
#   'node-link': 'o',
#   'non-experts': 'o',
#   'paper': 'abadi',
#   'scatter': 'o',
#   'units': 'o',
#   'venue': 'arXiv',
#   'year': 2016},
#  {'after': 'o',
#   'aggregated': 'x',
#   'algorithms': 'x',
#   'comparing': 'o',
#   'debugging': 'x',
#   'during': 'x',
#   'education': 'o',
#   'graph': 'o',
#   'instance-based': 'x',
#   'interactive-experimentation': 'o',
#   'interpretability': 'x',
#   'learned': 'o',
#   'line': 'o',
#   'model-developers': 'x',
#   'model-users': 'o',
#   'neurons': 'o',
#   'node-link': 'o',
#   'non-experts': 'o',
#   'paper': 'alsallakh',
#   'scatter': 'o',
# ...

# %%
papers = []
for datum in data:
    paper=[]
    paper.append('paper: ' + str(datum[0]) )
    paper.append('author: ' + str(datum[1]) )
    paper.append('year: ' + str(datum[2]) )
    paper.append('interpretability: ' + str(datum[3]) )
    paper.append('debugging: ' + str(datum[4]) )
    paper.append('comparing: ' + str(datum[5]) )
    paper.append('education: ' + str(datum[6]) )
    paper.append('model-developers: ' + str(datum[7]) )
    paper.append('model-users: ' + str(datum[8]) )
    paper.append('non-experts: ' + str(datum[9]) )
    paper.append('graph: ' + str(datum[10]) )
    paper.append('learned: ' + str(datum[11]) )
    paper.append('units: ' + str(datum[12]) )
    paper.append('neurons: ' + str(datum[13]) )
    paper.append('aggregated: ' + str(datum[14]) )
    paper.append('node-link: ' + str(datum[15]) )
    paper.append('scatter: ' + str(datum[16]) )
    paper.append('line: ' + str(datum[17]) )
    paper.append('instance-based: ' + str(datum[18]) )
    paper.append('interactive-experimentation: ' + str(datum[19]) )
    paper.append('algorithms: ' + str(datum[20]) )
    paper.append('during: ' + str(datum[21]) )
    paper.append('after: ' + str(datum[22]) )
    paper.append('venue: ' + str(datum[23]) )
    papers.append(paper)

# %%
papers
# Out:
# [['paper: abadi2016tensorflow',
#   'author: abadi',
#   'year: 2016',
#   'interpretability: x',
#   'debugging: x',
#   'comparing: x',
#   'education: o',
#   'model-developers: x',
#   'model-users: x',
#   'non-experts: o',
#   'graph: o',
#   'learned: o',
#   'units: o',
#   'neurons: o',
#   'aggregated: x',
#   'node-link: o',
#   'scatter: o',
#   'line: x',
#   'instance-based: o',
#   'interactive-experimentation: o',
#   'algorithms: o',
#   'during: x',
#   'after: x',
#   'venue: arXiv'],
#  ['paper: alsallakh2017convolutional',
#   'author: alsallakh',
#   'year: 2017',
#   'interpretability: x',
#   'debugging: x',
#   'comparing: o',
#   'education: o',
#   'model-developers: x',
#   'model-users: o',
#   'non-experts: o',
#   'graph: o',
#   'learned: o',
#   'units: x',
#   'neurons: o',
#   'aggregated: x',
#   'node-link: o',
#   'scatter: o',
#   'line: o',
#   'instance-based: x',
#   'interactive-experimentation: o',
#   'algorithms: x',
#   'during: x',
# ...

# %%
with open('papers.yml', 'w') as outfile:
    yaml.dump(papers, outfile, default_flow_style=False)
